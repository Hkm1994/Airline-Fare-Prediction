# %%
import pandas as pd
print("Pandas version:", pd.__version__)
print("Notebook is now using the venv!")
# Out:
# Pandas version: 2.3.3
# Notebook is now using the venv!

# %%
import pandas as pd

# Creating a quick "Flight Fare" table
data = {
    'Airline': ['IndiGo', 'Air India', 'Vistara'],
    'Price': [5500, 7200, 8900],
    'Status': ['On Time', 'Delayed', 'On Time']
}

df = pd.DataFrame(data)
df # This will show a nice table
# Out:
#      Airline  Price   Status
# 0     IndiGo   5500  On Time
# 1  Air India   7200  Delayed
# 2    Vistara   8900  On Time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
train_data=pd.read_excel(r"D:\ML Projects\Airline Fare Prediction\data/Data_Train.xlsx")

# %%
type(train_data.shape)
# Out:
# tuple

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data[train_data["Total_Stops"].isnull()]
train_data=train_data.dropna()

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data[train_data.duplicated(keep=False)].sort_values(by=train_data.columns.tolist())
# Out:
#         Airline Date_of_Journey    Source Destination                  Route  \
# 6321  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 9848  Air India      01/03/2019  Banglore   New Delhi  BLR → BOM → AMD → DEL
# 572   Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 8168  Air India      03/03/2019  Banglore   New Delhi              BLR → DEL
# 1495  Air India       1/04/2019   Kolkata    Banglore  CCU → DEL → COK → BLR
# ...         ...             ...       ...         ...                    ...
# 2870   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1535   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 3711   SpiceJet      24/03/2019  Banglore   New Delhi              BLR → DEL
# 2634    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
# 5470    Vistara      24/03/2019  Banglore   New Delhi              BLR → DEL
#
# ...

# %%
train_data=train_data.drop_duplicates()
train_data[train_data.duplicated(keep=False)].sort_values(by=train_data.columns.tolist())
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10462 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10462 non-null  object
#  1   Date_of_Journey  10462 non-null  object
#  2   Source           10462 non-null  object
#  3   Destination      10462 non-null  object
#  4   Route            10462 non-null  object
#  5   Dep_Time         10462 non-null  object
#  6   Arrival_Time     10462 non-null  object
#  7   Duration         10462 non-null  object
#  8   Total_Stops      10462 non-null  object
#  9   Additional_Info  10462 non-null  object
#  10  Price            10462 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 980.8+ KB

# %%
# Data feature engineering : Extract day, month and year

data= train_data.copy()
